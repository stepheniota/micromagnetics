# %%
## Take data generated by MuMax3 and plot STFMF color plot
## Stephen Iota
## Last Updated: 10.18
## Version: 0.0

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import fftpack

# %%
data = np.random.rand(3,100,1)
(times, mags, bfields) = data
#times, mags, bfields = np.loadtxt("table.txt",skiprows=1,unpack=True)

# %%
## Fourier transform into frequency domain
## convert t(s) --> f(Hz)
freqs = fftpack.fft(times)

# %%
final_data = np.zeros(data.shape)
final_data = freqs,mags,bfields

# %%
for i in bfields:
    if bfields[i] == bfields[i+1]
# Out:
#   File "<ipython-input-59-53eb603984b1>", line 2
#     if bfields[i] == bfields[i+1]
#                                  ^
# SyntaxError: invalid syntax
